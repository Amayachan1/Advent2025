# %%
# Input handling

with open("Day8_ex_input.txt", 'r') as input_file:
    input_raw = input_file.read().split('\n')

# Make a list with boxes coordinates
list_of_boxes = [tuple(map(int, box.split(','))) for box in input_raw]

print(list_of_boxes)
# Out:
# [(162, 817, 812), (57, 618, 57), (906, 360, 560), (592, 479, 940), (352, 342, 300), (466, 668, 158), (542, 29, 236), (431, 825, 988), (739, 650, 466), (52, 470, 668), (216, 146, 977), (819, 987, 18), (117, 168, 530), (805, 96, 715), (346, 949, 466), (970, 615, 88), (941, 993, 340), (862, 61, 35), (984, 92, 344), (425, 690, 689)]

# %%
# Function to calculate distance between boxes
from math import sqrt
    
def calculate_distance(box1, box2):

    dx = box1[0] - box2[0]
    dy = box1[1] - box2[1]
    dz = box1[2] - box2[2]

    distance = sqrt(dx**2 + dy**2 + dz**2)

    return(distance)

# %%
# # Set up a forest of circuits
# class Forest:
#     def __init__(self):
#         self.list_of_circuits=[]
    
#     def add_to_forest(self, circuit):
#         self.list_of_circuits.append(circuit)

#     def remove_from_forest(self, circuit):
#         self.list_of_circuits.remove(circuit)

# %%
# Set up a class for circuits

class Circuit:
    def __init__(self, coordinates):
        self.parent = self
        self.coordinates = coordinates
        self.size = 1

    def find_root(self):

        if self.parent == self:
            return self
        
        else:
            # Updating parents to the root
            self.parent = self.parent.find_root()
            return self.parent
        
    def merge_circuits(self, other):

        if self.find_root() == other.find_root():
            # print(f'{self.coordinates} and {other.coordinates} are already in the same circuit')
            return False
        
        else:
            size1 = self.parent.size
            size2 = other.parent.size
            if size1 < size2:
                # print(f'Merged {self.coordinates} (size {self.parent.size}) onto {other.coordinates} (size {other.parent.size})')
                other.parent.size += size1
                self.parent = other.parent
                # print(f'Size increased to {other.size}')
                
            else:
                # print(f'Merged {other.coordinates} (size {other.parent.size}) onto {self.coordinates} (size {self.parent.size})')
                self.parent.size += size2
                other.parent = self.parent
                # print(f'Size increased to {self.size}')

            return True

# %%
# Initialise all circuits
list_of_circuits = []

for box in list_of_boxes:
    # box_circuit = Circuit(box)
    list_of_circuits.append(Circuit(box))

# print([box.coordinates for  box in list_of_circuits])
# Out:
# [(162, 817, 812), (57, 618, 57), (906, 360, 560), (592, 479, 940), (352, 342, 300), (466, 668, 158), (542, 29, 236), (431, 825, 988), (739, 650, 466), (52, 470, 668), (216, 146, 977), (819, 987, 18), (117, 168, 530), (805, 96, 715), (346, 949, 466), (970, 615, 88), (941, 993, 340), (862, 61, 35), (984, 92, 344), (425, 690, 689)]

# %%
# Make a list of pairs
list_of_box_pairs = [(box1, box2) for i, box1 in enumerate(list_of_circuits) for box2 in list_of_circuits[i+1:]]

# Sort by distance, closest first
sorted_list_of_box_pairs = sorted(list_of_box_pairs, key=lambda pair: calculate_distance(pair[0].coordinates, pair[1].coordinates))

# %%
# circuit1 = list_of_circuits[0]
# circuit2 = list_of_circuits[1]
# circuit3 = list_of_circuits[2]
# circuit4 = list_of_circuits[4]

# circuit1.merge_circuits(circuit2)
# circuit3.merge_circuits(circuit4)
# circuit2.merge_circuits(circuit3)

# %%
connections = 0
i = 0

while connections != 10:
    
    box_pair = sorted_list_of_box_pairs[i]
    
    if box_pair[0].merge_circuits(box_pair[1]):
        connections += 1
    i += 1
# Out:
# Merged (425, 690, 689) (size 1) onto (162, 817, 812) (size 1)
# Size increased to 2
# Merged (431, 825, 988) (size 1) onto (162, 817, 812) (size 2)
# Size increased to 3
# Merged (805, 96, 715) (size 1) onto (906, 360, 560) (size 1)
# Size increased to 2
# (431, 825, 988) and (425, 690, 689) are already in the same circuit
# Merged (984, 92, 344) (size 1) onto (862, 61, 35) (size 1)
# Size increased to 2
# Merged (117, 168, 530) (size 1) onto (52, 470, 668) (size 1)
# Size increased to 2
# Merged (941, 993, 340) (size 1) onto (819, 987, 18) (size 1)
# Size increased to 2
# Merged (739, 650, 466) (size 1) onto (906, 360, 560) (size 2)
# Size increased to 3
# Merged (346, 949, 466) (size 1) onto (425, 690, 689) (size 3)
# Size increased to 1
# Merged (984, 92, 344) (size 2) onto (906, 360, 560) (size 3)
# Size increased to 5
# Merged (592, 479, 940) (size 1) onto (425, 690, 689) (size 4)
# Size increased to 1

# %%
# for box in sorted(list_of_circuits, key=lambda box: box.size, reverse=True):
#     print(f'Circuit {box.find_root().coordinates} (box {box.coordinates}) is size of {box.size}')
# Out:
# Circuit (162, 817, 812) (box (162, 817, 812)) is size of 5
# Circuit (906, 360, 560) (box (906, 360, 560)) is size of 5
# Circuit (52, 470, 668) (box (52, 470, 668)) is size of 2
# Circuit (819, 987, 18) (box (819, 987, 18)) is size of 2
# Circuit (862, 61, 35) (box (862, 61, 35)) is size of 2

# %%
list_of_roots = [box.find_root() for box in list_of_circuits]
list_of_sizes = {}

for root in list_of_roots:
    list_of_sizes[root.coordinates] = list_of_roots.count(root)

result = 1
for box in sorted(list_of_sizes, key=lambda box: list_of_sizes[box], reverse=True)[:3]:
    print(f'Root {box} appeared {list_of_sizes[box]} times')
    result *= list_of_sizes[box]

print(result)
# Out:
# Root (162, 817, 812) appeared 5 times
# Root (906, 360, 560) appeared 4 times
# Root (52, 470, 668) appeared 2 times
# 40
